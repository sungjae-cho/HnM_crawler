# %%
url_item = 'http://www.hm.com/us/product/35011?article=35011-D'

# %%
import urllib

# %%
handle = urllib.urlopen(url_item)
html_gunk =  handle.read()

# %%
html_gunk
# Out:
# '<!DOCTYPE html>\r\n<html lang="en" class="no-touch desktop">\r\n    <head>\r\n        <meta name="keywords" content="" />\r\n        <meta name="robots" content="index,follow"/>\r\n        <meta name="description" content="Light beige. Fitted jacket in woven fabric with notched lapels, welt front pockets, and back vent. Lined."/>\r\n        <meta property="og:type" content="website"/>\r\n        <meta property="og:title" content="H&M Fitted Jacket $34.99"/>\r\n        <meta property="og:description" content="Light beige. Fitted jacket in woven fabric with notched lapels, welt front pockets, and back vent. Lined."/>\r\n        <meta property="og:site_name" content="H&M"/>\r\n        <meta property="og:image" content="http://lp.hm.com/hmprod?set=source[/environment/2017/8HZ_0184_006R.jpg],rotate[0],width[4044],height[4728],x[0],y[-11],type[FASHION_FRONT]&hmver=0&call=url[file:/product/subdepartment/mediumPlus]"/>\r\n        <script type="text/javascript" src="/dtmonitor/dtagent630_jp_
# ...

# %%
handle.close()

# %%
import urllib2

# %%
handle2 = urllib2.urlopen(url_item)
html_gunk2 =  handle2.read()

# %%
html_gunk2
# Out:
# '\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!DOCTYPE html>\r\n\r\n<html class="no-js">\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<head>\r\n    \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n    \r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<!-- josh start -->\r\n<meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1.0,user-scalable=no">\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n\r\n<title>Women\'s Clothing & Fashion - shop the latest trends | H&M US</title>\r\n<meta property="og:title" content="Women&#39;s Clothing &amp; Fashion - shop the latest trends">\r\n<link rel="shortcut icon" type="image/x-icon" href="//s1-cdn.hm.com/global/hm-pattern-lib/5.11.4/images/favicon.ico">\r\n\r\n<!-- josh end -->\r\n<script type="text/javascript">\r\n    var hm = hm || {};\r\n    hm.api = hm.api || {};\r\n    hm.moduleConfig = hm.moduleConfig 
# ...
