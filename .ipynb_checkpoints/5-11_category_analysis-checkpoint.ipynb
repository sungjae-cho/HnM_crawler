# %% [markdown]
# # 1. Import the meta data of items

# %%
from interface import *

# %%
dict_items_info = import_items_info()

# %%
len(dict_items_info)
# Out:
# 5579

# %% [markdown]
# # 2. Digging all kinds of categories

# %%
for serial in dict_items_info:
    metricCategoryID = dict_items_info[serial]['metricCategoryID']
    # Delete the first and last strings
    categories = metricCategoryID.split('_')[1:-1] # without the first and the last
    print categories
# Out:
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TROUSERS']
# ['CASUAL', 'TROUSERS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['CASUAL', 'TROUSERS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['SKIRTS', 'SHORT']
# ['HM', 'MAN', 'JACKETS', 'COATS']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['DIVIDED', 'JACKETS', 'COATS', 'JACKETS']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['DIVIDED', 'TROUSERS', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MODERNCLASSICS', 'BLAZERS']
# ['MODERNCLASSICS', 'BLAZERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'VESTS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['MODERNCLASSICS', 'SHIRTS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['SKIRTS', 'SHORT']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['SKIRTS', 'SHORT']
# ['MODERNCLASSICS', 'DRESSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'PLUS', 'DRESSES']
# ['TOPS', 'LONG', 'SLEEVED']
# ['CASUAL', 'JACKETS', 'COATS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['SKIRTS', 'SHORT']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['HM', 'MAN', 'JACKETS', 'COATS']
# ['DIVIDED', 'TROUSERS', 'SHORTS']
# ['DIVIDED', 'TROUSERS', 'SHORTS']
# ['DIVIDED', 'TROUSERS', 'SHORTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CASUAL', 'SHIRTS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TROUSERS', 'DRESSED']
# ['PARTYWEAR', 'TOPS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['SHORTS', 'OTHERS']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'DRESSED']
# ['HM', 'PLUS', 'BOTTOMS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['JUMPERS', 'CARDIGANS']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'DRESSED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['SHORTS', 'OTHERS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'OTHERS']
# ['TROUSERS', 'DRESSED']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SKIRTS', 'SHORT']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['SHORTS', 'OTHERS']
# ['SKIRTS', 'SHORT']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['JEANS', 'STRAIGHT']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SHORTS', 'DENIMSHORTS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['DRESSES', 'JUMPSUITS', 'PARTYDRESSES']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TROUSERS', 'DRESSED']
# ['HM', 'PLUS', 'DRESSES']
# ['SKIRTS', 'SHORT']
# ['DIVIDED', 'JEANS', 'SKINNY', 'MORE', 'SKINNY']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'SHIRTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['SKIRTS', 'SHORT']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TROUSERS', 'LEGGINGS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CASUAL', 'TROUSERS']
# ['CASUAL', 'TROUSERS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CASUAL', 'TROUSERS']
# ['CASUAL', 'TROUSERS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TROUSERS', 'LEGGINGS']
# ['TSHIRT', 'VESTS']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['SHORTS', 'DENIMSHORTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['SKIRTS', 'SHORT']
# ['JEANS', 'SKINNY', 'SKINNYHIGH']
# ['JEANS', 'SKINNY', 'SKINNYHIGH']
# ['HM', 'PLUS', 'DRESSES']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['MODERNCLASSICS', 'SHIRTS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['PARTYWEAR', 'TOPS']
# ['MODERNCLASSICS', 'TOPS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['MODERNCLASSICS', 'DRESSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['MODERNCLASSICS', 'DRESSES']
# ['TROUSERS', 'SLIM']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['SHORTS', 'OTHERS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['JEANS', 'LOOSE']
# ['JEANS', 'STRAIGHT']
# ['SKIRTS', 'SHORT']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'MAN', 'SUITS', 'JACKETS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TROUSERS', 'DRESSED']
# ['SKIRTS', 'MIDI']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['SKIRTS', 'SHORT']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['HM', 'PLUS', 'JACKETS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['HM', 'MAN', 'SHORTS']
# ['HM', 'MAN', 'SHORTS']
# ['HM', 'MAN', 'SHORTS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['SHORTS', 'OTHERS']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'OTHERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SHORTS', 'OTHERS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['SHORTS', 'OTHERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['MODERNCLASSICS', 'DRESSES']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['CASUAL', 'SHIRTS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'BASICS', 'BOTTOMS']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['JEANS', 'LOOSE']
# ['JEANS', 'LOOSE']
# ['JEANS', 'LOOSE']
# ['JEANS', 'LOOSE']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'OTHERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SHORTS', 'OTHERS']
# ['SKIRTS', 'MIDI']
# ['SWIMWEAR', 'SWIMSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['JEANS', 'SHAPING']
# ['JEANS', 'SHAPING']
# ['JEANS', 'SHAPING']
# ['JEANS', 'SHAPING']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['MODERNCLASSICS', 'SKIRTS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['TROUSERS', 'DRESSED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'COATS']
# ['HM', 'PLUS', 'DRESSES']
# ['HM', 'PLUS', 'DRESSES']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['HM', 'MAN', 'SHIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['HM', 'PLUS', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['HM', 'MAN', 'SHORTS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['JUMPERS', 'CARDIGANS']
# ['JUMPERS', 'CARDIGANS']
# ['JUMPERS', 'CARDIGANS']
# ['JEANS', 'SLIM']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['JEANS', 'SLIM']
# ['HM', 'PLUS', 'BOTTOMS']
# ['TROUSERS', 'DRESSED']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['SPORTSWEAR', 'TOPS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['BASICS', 'TOPS']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['TROUSERS', 'DRESSED']
# ['JEANS', 'BOOTCUT']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['MODERNCLASSICS', 'TOPS']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['JEANS', 'SLIM', 'MORE', 'SLIM']
# ['PARTYWEAR', 'TOPS']
# ['PARTYWEAR', 'TOPS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['HM', 'MAN', 'JACKETS', 'COATS']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['MODERNCLASSICS', 'TOPS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'BASICS', 'SHORTS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'MIDI']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['MODERNCLASSICS', 'TOPS']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['SKIRTS', 'MIDI']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['JUMPERS', 'CARDIGANS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['JACKETS', 'COATS', 'COATS']
# ['MODERNCLASSICS', 'TOPS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['JACKETS', 'COATS', 'COATS']
# ['HM', 'PLUS', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'PLUS', 'TOPS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['JACKETS', 'COATS', 'COATS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['CASUAL', 'JACKETS', 'COATS']
# ['CASUAL', 'SHIRTS']
# ['JACKETS', 'COATS', 'COATS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['MODERNCLASSICS', 'DRESSES']
# ['SKIRTS', 'MIDI']
# ['MODERNCLASSICS', 'DRESSES']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['SKIRTS', 'SHORT']
# ['TSHIRT', 'VESTS']
# ['TSHIRT', 'VESTS']
# ['CASUAL', 'TROUSERS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['SKIRTS', 'SHORT']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['TSHIRT', 'VESTS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['JEANS', 'STRAIGHT']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['SHORTS', 'OTHERS']
# ['MODERN-CLASSICS', 'TROUSERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['SPORTSWEAR', 'JACKETS']
# ['SKIRTS', 'SHORT']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['PARTYWEAR', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['PARTYWEAR', 'TOPS']
# ['MODERNCLASSICS', 'DRESSES']
# ['JACKETS', 'COATS', 'JACKETS']
# ['MODERNCLASSICS', 'TOPS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['SHORTS', 'DENIMSHORTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['HM', 'PLUS', 'DRESSES']
# ['SPORTSWEAR', 'TOPS']
# ['CASUAL', 'SHORTS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['CASUAL', 'SHORTS']
# ['CASUAL', 'SHORTS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['HM', 'PLUS', 'BOTTOMS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'DRESSES']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SKIRTS', 'SHORT']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['CASUAL', 'SHIRTS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TROUSERS', 'DRESSED']
# ['JUMPERS', 'CARDIGANS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['MATERNITY', 'WEAR', 'JACKETS']
# ['SPORTSWEAR', 'TOPS']
# ['CASUAL', 'SHIRTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['MODERNCLASSICS', 'TOPS']
# ['TROUSERS', 'DRESSED']
# ['TROUSERS', 'DRESSED']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'PLUS', 'TOPS']
# ['PARTYWEAR', 'TOPS']
# ['DIVIDED', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['SHIRTS', 'DRESSED']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'PLUS', 'JEANS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['SHORTS', 'OTHERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['BASICS', 'CARDIGANSJUMPERS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['SPORTSWEAR', 'TOPS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'MAN', 'SUITS', 'JACKETS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MATERNITY', 'WEAR', 'JEANS']
# ['MATERNITY', 'WEAR', 'JEANS']
# ['MODERNCLASSICS', 'SKIRTS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['MODERNCLASSICS', 'SKIRTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['DIVIDED', 'TROUSERS', 'SHORTS']
# ['DIVIDED', 'TROUSERS', 'SHORTS']
# ['DIVIDED', 'TROUSERS', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'JACKETS']
# ['TROUSERS', 'DRESSED']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['MODERNCLASSICS', 'DRESSES']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['SHORTS', 'DENIMSHORTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['TROUSERS', 'LOOSE']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['HM', 'PLUS', 'DRESSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'PLUS', 'DRESSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['HOODIES', 'SWEATSHIRT']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['JACKETS', 'COATS', 'COATS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TROUSERS', 'LOOSE']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['HM', 'MAN', 'SHIRTS']
# ['HM', 'MAN', 'SHIRTS']
# ['HM', 'MAN', 'SHIRTS']
# ['HM', 'PLUS', 'TOPS']
# ['HM', 'PLUS', 'TOPS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['JACKETS', 'COATS', 'COATS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['DIVIDED', 'BASICS', 'SHORTS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['DIVIDED', 'BASICS', 'SHORTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['SHORTS', 'DENIMSHORTS']
# ['HM', 'MAN', 'SHIRTS']
# ['HM', 'PLUS', 'DRESSES']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'DRESSED']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['HM', 'PLUS', 'TOPS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JUMPERS', 'CARDIGANS']
# ['SWIMWEAR', 'SWIMSUITS']
# ['TROUSERS', 'CHINOS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['MODERNCLASSICS', 'DRESSES']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['HM', 'PLUS', 'BOTTOMS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SHIRTS', 'CASUAL']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['HM', 'PLUS', 'BOTTOMS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'BASICS', 'JOGGERS', 'SWEATPANTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['DIVIDED', 'BASICS', 'JOGGERS', 'SWEATPANTS']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['DIVIDED', 'BASICS', 'JOGGERS', 'SWEATPANTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['DIVIDED', 'BASICS', 'JOGGERS', 'SWEATPANTS']
# ['HM', 'PLUS', 'TOPS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['SHORTS', 'OTHERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'PARKAS']
# ['HM', 'PLUS', 'JEANS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['HM', 'PLUS', 'TOPS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['PARTYWEAR', 'BOTTOMS']
# ['HM', 'PLUS', 'JACKETS']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SKIRTS', 'LONG']
# ['JACKETS', 'COATS', 'JACKETS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['SKIRTS', 'SHORT']
# ['SPORTSWEAR', 'BOTTOMS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['TOPS', 'LONG', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['SHORTS', 'OTHERS']
# ['SKIRTS', 'LONG']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['SHIRTS', 'DRESSED']
# ['SKIRTS', 'LONG']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'TURTLENECKS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'TURTLENECKS']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['JEANS', 'LOOSE']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'OTHERS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['JEANS', 'SLIM', 'LOW']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['JEANS', 'SLIM', 'LOW']
# ['JEANS', 'SLIM', 'LOW']
# ['JEANS', 'SLIM', 'LOW']
# ['SPORTSWEAR', 'BOTTOMS']
# ['MODERNCLASSICS', 'DRESSES']
# ['MODERNCLASSICS', 'DRESSES']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['HM', 'PLUS', 'JACKETS']
# ['HM', 'PLUS', 'JACKETS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['HM', 'PLUS', 'BOTTOMS']
# ['JEANS', 'SKINNY', 'SKINNYREGULAR']
# ['JEANS', 'SKINNY', 'SKINNYREGULAR']
# ['JEANS', 'SKINNY', 'SKINNYREGULAR']
# ['JEANS', 'SKINNY', 'SKINNYREGULAR']
# ['JEANS', 'SKINNY', 'SKINNYREGULAR']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'BASICS', 'CARDIGANS', 'JUMPERS']
# ['MODERNCLASSICS', 'BLAZERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'JACKETS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['SPORTSWEAR', 'JACKETS']
# ['JEANS', 'LOOSE']
# ['HM', 'PLUS', 'JEANS']
# ['MODERNCLASSICS', 'TOPS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['JACKETS', 'COATS', 'PARKAS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['CASUAL', 'SHORTS']
# ['CASUAL', 'SHORTS']
# ['CASUAL', 'SHORTS']
# ['CASUAL', 'SHORTS']
# ['SKIRTS', 'SHORT']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['SHORTS', 'OTHERS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TROUSERS', 'DRESSED']
# ['TROUSERS', 'DRESSED']
# ['TROUSERS', 'LOOSE']
# ['CASUAL', 'SHIRTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DRESSES', 'JUMPSUITS', 'PARTYDRESSES']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['CASUAL', 'SHIRTS']
# ['CASUAL', 'SHIRTS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['TSHIRT', 'VESTS']
# ['TSHIRT', 'VESTS']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['JEANS', 'STRAIGHT']
# ['JEANS', 'STRAIGHT']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['HM', 'MAN', 'SUITS', 'JACKETS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['SKIRTS', 'MIDI']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['JACKETS', 'COATS', 'JACKETS']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['HM', 'PLUS', 'DRESSES']
# ['SPORTSWEAR', 'JACKETS']
# ['SPORTSWEAR', 'JACKETS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['SHIRTS', 'DRESSED']
# ['HM', 'PLUS', 'BOTTOMS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['JEANS', 'STRAIGHT']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['TOPS', 'CROPTOPS']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['DIVIDED', 'BASICS', 'DRESSES', 'SKIRTS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['SPORTSWEAR', 'TOPS']
# ['CASUAL', 'SHIRTS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['JEANS', 'SLIM']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['JEANS', 'SLIM']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['MODERNCLASSICS', 'DRESSES']
# ['HM', 'PLUS', 'TOPS']
# ['MODERNCLASSICS', 'DRESSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['PARTYWEAR', 'BOTTOMS']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'PLUS', 'TOPS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'MAN', 'SHIRTS']
# ['HM', 'MAN', 'SHIRTS']
# ['HM', 'MAN', 'SHIRTS']
# ['HM', 'MAN', 'SHIRTS']
# ['JEANS', 'SHAPING']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['HM', 'PLUS', 'JEANS']
# ['HM', 'PLUS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['MODERNCLASSICS', 'BLAZERS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['HM', 'MAN', 'SHIRTS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['DIVIDED', 'JACKETS', 'COATS', 'JACKETS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['PARTYWEAR', 'TOPS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['SHORTS', 'OTHERS']
# ['TROUSERS', 'DRESSED']
# ['SPORTSWEAR', 'JACKETS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['SKIRTS', 'SHORT']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['JEANS', 'SKINNY', 'SKINNYHIGH']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['TROUSERS', 'LOOSE']
# ['SPORTSWEAR', 'TOPS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['PARTYWEAR', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['SPORTSWEAR', 'TOPS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['HM', 'MAN', 'JACKETS', 'COATS']
# ['HM', 'PLUS', 'TOPS']
# ['DIVIDED', 'JACKETS', 'COATS', 'JACKETS']
# ['DIVIDED', 'JACKETS', 'COATS', 'JACKETS']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['BASICS', 'TOPS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['BASICS', 'TOPS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['BASICS', 'TOPS']
# ['JACKETS', 'COATS', 'COATS']
# ['SHORTS', 'OTHERS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SHIRTS', 'DRESSED']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['JEANS', 'SLIM']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'DRESSED']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['MATERNITY', 'WEAR', 'JEANS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['PARTYWEAR', 'TOPS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'TURTLENECKS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['JEANS', 'LOOSE']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['MODERNCLASSICS', 'DRESSES']
# ['SKIRTS', 'SHORT']
# ['MODERNCLASSICS', 'SKIRTS']
# ['MODERNCLASSICS', 'SKIRTS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'CROPTOPS']
# ['TOPS', 'CROPTOPS']
# ['TOPS', 'CROPTOPS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TROUSERS', 'LOOSE']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['SHIRTS', 'DRESSED']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'JACKETS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'COATS']
# ['PARTYWEAR', 'DRESSES', 'JUMPSUITS']
# ['SKIRTS', 'LONG']
# ['JEANS', 'STRAIGHT']
# ['JEANS', 'STRAIGHT']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SKIRTS', 'SHORT']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'MAN', 'SHIRTS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['PARTYWEAR', 'TOPS']
# ['PARTYWEAR', 'TOPS']
# ['SHORTS', 'OTHERS']
# ['HM', 'PLUS', 'TOPS']
# ['HM', 'PLUS', 'TOPS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'SHIRTS']
# ['CASUAL', 'SHIRTS']
# ['CASUAL', 'SHIRTS']
# ['SPORTSWEAR', 'JACKETS']
# ['PARTYWEAR', 'BOTTOMS']
# ['HM', 'MAN', 'SUITS', 'JACKETS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['TROUSERS', 'DRESSED']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'PLUS', 'TOPS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TOPS', 'LONG', 'SLEEVED']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['MODERNCLASSICS', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['MODERNCLASSICS', 'TOPS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'CROPTOPS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['HM', 'PLUS', 'TOPS']
# ['HM', 'PLUS', 'TOPS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['BASICS', 'TROUSERS']
# ['BASICS', 'TROUSERS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['DIVIDED', 'JEANS', 'SLIM', 'SLIM', 'LOW']
# ['DIVIDED', 'JEANS', 'SLIM', 'SLIM', 'LOW']
# ['MODERNCLASSICS', 'DRESSES']
# ['MODERNCLASSICS', 'DRESSES']
# ['DIVIDED', 'JEANS', 'SLIM', 'SLIM', 'LOW']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['DIVIDED', 'BASICS', 'JOGGERS', 'SWEATPANTS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['HM', 'MAN', 'SHIRTS']
# ['PARTYWEAR', 'BOTTOMS']
# ['DIVIDED', 'BASICS', 'JOGGERS', 'SWEATPANTS']
# ['PARTYWEAR', 'BOTTOMS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['PARTYWEAR', 'TOPS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['JEANS', 'LOOSE']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHIRTS', 'BLOUSES', 'TUNICS']
# ['SKIRTS', 'MIDI']
# ['SPORTSWEAR', 'BOTTOMS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['CASUAL', 'CARDIGANS', 'JUMPERS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['MODERNCLASSICS', 'BLAZERS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['HM', 'PLUS', 'JACKETS']
# ['HM', 'MAN', 'SUITS', 'JACKETS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['JACKETS', 'COATS', 'JACKETS']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['MODERNCLASSICS', 'BLAZERS']
# ['MODERNCLASSICS', 'DRESSES']
# ['DRESSES', 'JUMPSUITS', 'PARTYDRESSES']
# ['JACKETS', 'COATS', 'JACKETS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['HM', 'PLUS', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['MODERNCLASSICS', 'SKIRTS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['SHIRTS', 'CASUAL']
# ['SHIRTS', 'CASUAL']
# ['JACKETS', 'COATS', 'JACKETS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['TOPS', 'CROPTOPS']
# ['TOPS', 'CROPTOPS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SWIMWEAR', 'SWIMSUITS']
# ['BASICS', 'CARDIGANSJUMPERS']
# ['DRESSES', 'JUMPSUITS', 'PARTYDRESSES']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['BASICS', 'CARDIGANSJUMPERS']
# ['BASICS', 'CARDIGANSJUMPERS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['HM', 'MAN', 'SUITS', 'JACKETS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['PARTYWEAR', 'BOTTOMS']
# ['JACKETS', 'COATS', 'PARKAS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['JACKETS', 'COATS', 'COATS']
# ['SKIRTS', 'SHORT']
# ['CASUAL', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['JACKETS', 'COATS', 'JACKETS']
# ['SKIRTS', 'LONG']
# ['SPORTSWEAR', 'BOTTOMS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TROUSERS', 'LOOSE']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['HM', 'PLUS', 'DRESSES']
# ['TOPS', 'LONG', 'SLEEVED']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['CASUAL', 'SHIRTS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['JACKETS', 'COATS', 'JACKETS']
# ['SKIRTS', 'SHORT']
# ['JACKETS', 'COATS', 'COATS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SKIRTS', 'SHORT']
# ['JACKETS', 'COATS', 'JACKETS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TROUSERS', 'LOOSE']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['HM', 'PLUS', 'TOPS']
# ['MODERNCLASSICS', 'DRESSES']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['SHORTS', 'OTHERS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['HM', 'PLUS', 'JEANS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['SPORTSWEAR', 'TOPS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['HM', 'MAN', 'JACKETS', 'COATS']
# ['HM', 'MAN', 'SHORTS']
# ['HM', 'MAN', 'SHORTS']
# ['HM', 'MAN', 'SHORTS']
# ['HM', 'MAN', 'SHORTS']
# ['HM', 'MAN', 'SHORTS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['SKIRTS', 'SHORT']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['MODERNCLASSICS', 'TOPS']
# ...
# ['CARDIGANS', 'JUMPERS', 'TURTLENECKS']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['MODERNCLASSICS', 'SKIRTS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['JEANS', 'FLARE']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['DIVIDED', 'BASICS', 'HOODIES', 'SWEATSHIRTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['HM', 'PLUS', 'TOPS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['BASICS', 'BOTTOMS']
# ['BASICS', 'BOTTOMS']
# ['BASICS', 'BOTTOMS']
# ['BASICS', 'BOTTOMS']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['TROUSERS', 'LOOSE']
# ['DIVIDED', 'CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['HM', 'PLUS', 'JACKETS']
# ['TROUSERS', 'DRESSED']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['JACKETS', 'COATS', 'JACKETS']
# ['MODERNCLASSICS', 'TOPS']
# ['MODERNCLASSICS', 'TOPS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['HM', 'MAN', 'JACKETS', 'COATS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['MODERNCLASSICS', 'TOPS']
# ['MODERNCLASSICS', 'TOPS']
# ['MODERNCLASSICS', 'TOPS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['BASICS', 'TROUSERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TROUSERS', 'DRESSED']
# ['SPORTSWEAR', 'BOTTOMS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['BASICS', 'TROUSERS']
# ['BASICS', 'TROUSERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['MODERNCLASSICS', 'DRESSES']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['CASUAL', 'SHIRTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['MODERNCLASSICS', 'DRESSES']
# ['CASUAL', 'SHIRTS', 'BLOUSES']
# ['MODERNCLASSICS', 'SKIRTS']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'DRESSED']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['TROUSERS', 'DRESSED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'OTHERS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'OTHERS']
# ['JEANS', 'STRAIGHT']
# ['JEANS', 'STRAIGHT']
# ['DRESSES', 'JUMPSUITS', 'PARTYDRESSES']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['JEANS', 'STRAIGHT']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DIVIDED', 'TROUSERS', 'SHORTS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['JEANS', 'STRAIGHT']
# ['JEANS', 'STRAIGHT']
# ['HM', 'PLUS', 'BOTTOMS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SHIRTS', 'DRESSED']
# ['TROUSERS', 'DRESSED']
# ['TROUSERS', 'SLIM']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['SKIRTS', 'SHORT']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['CASUAL', 'SHIRTS']
# ['HM', 'MAN', 'SUITS', 'JACKETS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['PARTYWEAR', 'TOPS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['TROUSERS', 'LEGGINGS']
# ['TROUSERS', 'LEGGINGS']
# ['TROUSERS', 'LEGGINGS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DRESSES', 'JUMPSUITS', 'PARTYDRESSES']
# ['SHORTS', 'OTHERS']
# ['HM', 'PLUS', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['JEANS', 'SKINNY', 'SKINNYLOW']
# ['SHIRTS', 'DRESSED']
# ['HM', 'PLUS', 'DRESSES']
# ['SHIRTS', 'DRESSED']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['HM', 'PLUS', 'DRESSES']
# ['SHIRTS', 'BLOUSES', 'TUNICS']
# ['TROUSERS', 'DRESSED']
# ['TROUSERS', 'DRESSED']
# ['TROUSERS', 'DRESSED']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DIVIDED', 'SHIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['HM', 'MAN', 'JACKETS', 'COATS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['MODERN-CLASSICS', 'TROUSERS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['TROUSERS', 'LOOSE']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['JACKETS', 'COATS', 'JACKETS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['SHORTS', 'OTHERS']
# ['SKIRTS', 'MIDI']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'JEANS', 'STRAIGHT']
# ['DIVIDED', 'JEANS', 'STRAIGHT']
# ['DIVIDED', 'JEANS', 'STRAIGHT']
# ['TSHIRT', 'LONG', 'SLEEVED']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['MODERNCLASSICS', 'DRESSES']
# ['MODERNCLASSICS', 'DRESSES']
# ['MODERNCLASSICS', 'DRESSES']
# ['HM', 'PLUS', 'DRESSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['DIVIDED', 'SHIRTS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['TROUSERS', 'DRESSED']
# ['TROUSERS', 'DRESSED']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TROUSERS', 'LOOSE']
# ['MATERNITY', 'WEAR', 'TOPS']
# ['JACKETS', 'COATS', 'COATS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['SHORTS', 'OTHERS']
# ['SHORTS', 'DENIMSHORTS']
# ['SHORTS', 'DENIMSHORTS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['HM', 'PLUS', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['HM', 'PLUS', 'DRESSES']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['SPORTSWEAR', 'TOPS']
# ['JEANS', 'SKINNY', 'SKINNYHIGH']
# ['JEANS', 'SKINNY', 'SKINNYHIGH']
# ['JEANS', 'SKINNY', 'SKINNYHIGH']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JEANS', 'SKINNY', 'SKINNYHIGH']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['MODERNCLASSICS', 'DRESSES']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'SHIRTS']
# ['DIVIDED', 'TOPS', 'CROPTOPS']
# ['JEANS', 'SKINNY', 'SKINNYHIGH']
# ['HM', 'MAN', 'SHIRTS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['MODERNCLASSICS', 'SHIRTS']
# ['HM', 'PLUS', 'TOPS']
# ['HM', 'PLUS', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SPORTSWEAR', 'TOPS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['MODERNCLASSICS', 'DRESSES']
# ['MATERNITY', 'WEAR', 'DRESSES']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['PARTYWEAR', 'BOTTOMS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['BASICS', 'TOPS']
# ['BASICS', 'TOPS']
# ['TOPS', 'CROPTOPS']
# ['TOPS', 'CROPTOPS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['HM', 'MAN', 'CARDIGANS', 'JUMPERS']
# ['HM', 'MAN', 'TROUSERS', 'JEANS']
# ['HM', 'PLUS', 'JACKETS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['MATERNITY', 'WEAR', 'BOTTOMS']
# ['BLAZERS', 'KIMONOS', 'BLAZERS']
# ['DRESSES', 'JUMPSUITS', 'PARTYDRESSES']
# ['HM', 'PLUS', 'DRESSES']
# ['TROUSERS', 'DRESSED']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'JACKETS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['HM', 'PLUS', 'DRESSES']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['HM', 'MAN', 'SHIRTS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'DRESSED']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TOPS', 'LONG', 'SLEEVED']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['DIVIDED', 'JEANS', 'STRAIGHT']
# ['SKIRTS', 'SHORT']
# ['SKIRTS', 'SHORT']
# ['BLAZERS', 'SUITS', 'BLAZERS']
# ['HM', 'MAN', 'SHIRTS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TSHIRT', 'SHORT', 'SLEEVED']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'SHIRTS']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['PARTYWEAR', 'TOPS']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['SHIRTS', 'CASUAL']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['SHORTS', 'OTHERS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'PLUS', 'DRESSES']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SKINNY', 'REGULAR']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['SHIRTS', 'BLOUSES', 'TUNICS']
# ['SHIRTS', 'BLOUSES', 'TUNICS']
# ['SHIRTS', 'BLOUSES', 'TUNICS']
# ['PARTYWEAR', 'BOTTOMS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['CASUAL', 'HOODIES', 'SWEATSHIRTS']
# ['TOPS', 'LONG', 'SLEEVED']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['SHIRTS', 'BLOUSES', 'TUNICS']
# ['HM', 'PLUS', 'TOPS']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['DIVIDED', 'BASICS', 'TOPS']
# ['SKIRTS', 'MIDI']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['DIVIDED', 'HOODIES', 'SWEATSHIRT']
# ['JACKETS', 'COATS', 'COATS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['SPORTSWEAR', 'TOPS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CARDIGANS', 'JUMPERS', 'JUMPERS']
# ['HM', 'PLUS', 'DRESSES']
# ['SPORTSWEAR', 'TOPS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'PLUS', 'TOPS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['MODERNCLASSICS', 'SKIRTS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['JACKETS', 'COATS', 'JACKETS']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['TOPS', 'SHORT', 'SLEEVED']
# ['HM', 'MAN', 'TSHIRTS', 'VESTS']
# ['HM', 'PLUS', 'BOTTOMS']
# ['MODERN-CLASSICS', 'CARDIGANS', 'JUMPERS']
# ['HM', 'PLUS', 'TOPS']
# ['DRESSES', 'JUMPSUITS', 'SHORT']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['EVERYDAY', 'FASHION', 'DRESSES', 'JUMPSUITS']
# ['JACKETS', 'COATS', 'COATS']
# ['SHORTS', 'OTHERS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['JACKETS', 'COATS', 'JACKETS']
# ['MODERNCLASSICS', 'DRESSES']
# ['MODERNCLASSICS', 'DRESSES']
# ['HM', 'PLUS', 'TOPS']
# ['BASICS', 'DRESSES', 'SKIRTS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['SPORTSWEAR', 'BOTTOMS']
# ['CASUAL', 'SHIRTS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['EVERYDAY', 'FASHION', 'SHORTS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['HM', 'PLUS', 'JEANS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['EVERYDAY', 'FASHION', 'TROUSERS', 'JEANS']
# ['DRESSES', 'JUMPSUITS', 'MIDI']
# ['TROUSERS', 'SLIM']
# ['CASUAL', 'SHORTS']
# ['CASUAL', 'SHORTS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['CARDIGANS', 'JUMPERS', 'HOODIES']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['DRESSES', 'JUMPSUITS', 'LONG']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SUPERSKINNY']
# ['DIVIDED', 'JEANS', 'SKINNY', 'SUPERSKINNY']
# ['TOPS', 'LONG', 'SLEEVED']
# ['MODERNCLASSICS', 'TROUSERS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['MODERNCLASSICS', 'TROUSERS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['CASUAL', 'TROUSERS', 'JEANS']
# ['MODERNCLASSICS', 'DRESSES']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['CASUAL', 'TSHIRTS', 'VESTS']
# ['SKIRTS', 'SHORT']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['SKIRTS', 'SHORT']
# ['CARDIGANS', 'JUMPERS', 'CARDIGANS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['TOPS', 'VESTS', 'SLEEVELESS']
# ['HM', 'MAN', 'SUITS', 'TROUSERS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['DIVIDED', 'DRESSES', 'JUMPSUITS']
# ['JACKETS', 'COATS', 'BOMBERS']
# ['HM', 'PLUS', 'JEANS']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['SHIRTS', 'BLOUSES', 'BLOUSES']
# ['HM', 'MAN', 'HOODIES', 'SWEATSHIRTS']
# ['TROUSERS', 'JOGGERS', 'SWEATPANTS']
# ['SHIRTS', 'BLOUSES', 'SHIRTS']

# %%
set_category = set()
set_category_first = set()
set_category_last = set()
for serial in dict_items_info:
    metricCategoryID = dict_items_info[serial]['metricCategoryID']
    # Delete the first and last strings
    categories = metricCategoryID.split('_')[1:-1]
    set_category_first.add(categories[0])
    set_category_last.add(categories[-1])
    for category in categories:
        set_category.add(category)
print "set_category:\n", set_category, '\n'
print "set_category_first:\n", set_category_first, '\n'
print "set_category_last:\n", set_category_last, '\n'
# Out:
# set_category:
# set(['SHORT', 'SWIMWEAR', 'SUPERSKINNY', 'BOOTCUT', 'TOPS', 'SUITS', 'COATS', 'TSHIRT', 'BOMBERS', 'LEGGINGS', 'SHIRTS', 'HM', 'MORESKINNY', 'CARDIGANSJUMPERS', 'CARDIGANS', 'CASUAL', 'SPORTSWEAR', 'JUMPSUIT', 'SWIMSUITS', 'BOTTOMS', 'FASHION', 'DENIMSHORTS', 'BLOUSES', 'SWEATSHIRTS', 'LOW', 'SKINNYLOW', 'CROPTOPS', 'LONG', 'EVERYDAY', 'PARKAS', 'PLUS', 'JOGGERS', 'PARTYDRESSES', 'PARTYWEAR', 'SHAPING', 'JUMPERS', 'SLIM', 'VESTS', 'SHORTS', 'DRESSED', 'DIVIDED', 'KIMONOS', 'TURTLENECKS', 'BASICS', 'MODERNCLASSICS', 'WEAR', 'TUNICS', 'OTHERS', 'SWEATSHIRT', 'DRESSES', 'JUMPSUITS', 'SWEATPANTS', 'SLEEVED', 'HOODIES', 'SKINNYREGULAR', 'FLARE', 'MIDI', 'TSHIRTS', 'SLEEVELESS', 'STRAIGHT', 'LOOSE', 'JEANS', 'SKINNYHIGH', 'CHINOS', 'BLAZERS', 'REGULAR', 'MATERNITY', 'MODERN-CLASSICS', 'JACKETS', 'TROUSERS', 'SKINNY', 'MORE', 'SKIRTS', 'MAN'])
#
# set_category_first:
# set(['TOPS', 'TSHIRT', 'SHIRTS', 'HM', 'CARDIGANS', 'EVERYDAY', 'SPORTSWEAR', 'CASUAL', 'MATERNITY', 'JUMPERS', 'SHORTS', 'DIVIDED', 'MODERNCLASSICS', 'DRESSES', 'BASICS', 'HOODIES', 'JEANS', 'SWIMWEAR', 'BLAZERS', 'PARTYWEAR', 'MODERN-CLASSICS', 'JACKETS', 'TROUSERS', 'SKIRTS'])
#
# set_category_last:
# set(['SHORT', 'SUPERSKINNY', 'TOPS', 'COATS', 'SKINNYHIGH', 'BOMBERS', 'LEGGINGS', 'SHIRTS', 'MORESKINNY', 'CARDIGANSJUMPERS', 'CARDIGANS', 'CASUAL', 'PARKAS', 'JUMPSUIT', 'DENIMSHORTS', 'BLOUSES', 'SWEATSHIRTS', 'LOW', 'SKINNYLOW', 'CROPTOPS', 'LONG', 'SWIMSUITS', 'TURTLENECKS', 'PARTYDRESSES', 'SHAPING', 'JUMPERS', 'SLIM', 'VESTS', 'SHORTS', 'DRESSED', 'TROUSERS', 'TUNICS', 'OTHERS', 'SWEATSHIRT', 'DRESSES', 'JUMPSUITS', 'SWEATPANTS', 'SLEEVED', 'HOODIES', 'SKINNYREGULAR', 'FLARE', 'MIDI', 'CHINOS', 'SLEEVELESS', 'STRAIGHT', 'LOOSE', 'JEANS', 'BLAZERS', 'REGULAR', 'JACKETS', 'BOTTOMS', 'SKINNY', 'SKIRTS', 'BOOTCUT'])

# %%
def print_has(category):
    for serial in dict_items_info:
        metricCategoryID = dict_items_info[serial]['metricCategoryID']
        # Delete the first and last strings
        categories = metricCategoryID.split('_')[1:-1]
        if category in categories:
            print categories
            print dict_items_info[serial]['url']

# %% [markdown]
# ## 'BOMBERS'?

# %%
print_has('BOMBERS')
# Out:
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/65879?article=65879-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/54053?article=54053-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/65967?article=65967-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/65967?article=65967-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/57179?article=57179-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61358?article=61358-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62741?article=62741-F
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62741?article=62741-C
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62722?article=62722-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/52360?article=52360-H
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61173?article=61173-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/52360?article=52360-G
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/52360?article=52360-J
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/49368?article=49368-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/58557?article=58557-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/63887?article=63887-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/65416?article=65416-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61396?article=61396-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/54295?article=54295-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/54295?article=54295-E
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/43709?article=43709-N
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/43709?article=43709-M
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/64739?article=64739-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/43709?article=43709-D
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/43709?article=43709-P
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/63487?article=63487-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62344?article=62344-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/67609?article=67609-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/67285?article=67285-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/50763?article=50763-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62975?article=62975-E
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62975?article=62975-F
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62975?article=62975-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62741?article=62741-D
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61849?article=61849-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/54243?article=54243-C
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/59470?article=59470-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/54192?article=54192-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61047?article=61047-F
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61047?article=61047-E
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62098?article=62098-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/52146?article=52146-F
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62323?article=62323-D
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62323?article=62323-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62323?article=62323-C
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61782?article=61782-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/59506?article=59506-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/69394?article=69394-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/69394?article=69394-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61355?article=61355-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/55047?article=55047-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/10614?article=10614-T
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/10614?article=10614-U
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/10614?article=10614-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/10614?article=10614-E
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/65478?article=65478-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/67754?article=67754-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61923?article=61923-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/40951?article=40951-J
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/40951?article=40951-I
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/40951?article=40951-D
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/37115?article=37115-C
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/59374?article=59374-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/54243?article=54243-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61333?article=61333-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61333?article=61333-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61333?article=61333-C
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/69645?article=69645-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/57856?article=57856-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61047?article=61047-D
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/63231?article=63231-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/64851?article=64851-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61447?article=61447-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/62339?article=62339-D
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61869?article=61869-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/66534?article=66534-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/61466?article=61466-B
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/58598?article=58598-A
# ['JACKETS', 'COATS', 'BOMBERS']
# http://www.hm.com/us/product/41233?article=41233-B

# %% [markdown]
# ## 'LEGGINGS'

# %%
print_has('LEGGINGS')
# Out:
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/54464?article=54464-D
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/58046?article=58046-F
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/53672?article=53672-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/54464?article=54464-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/65071?article=65071-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/51660?article=51660-C
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/54783?article=54783-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/66954?article=66954-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/68393?article=68393-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/67419?article=67419-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/67419?article=67419-B
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/69519?article=69519-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/65824?article=65824-A
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/61279?article=61279-B
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/66032?article=66032-C
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/66032?article=66032-B
# ['TROUSERS', 'LEGGINGS']
# http://www.hm.com/us/product/66032?article=66032-A

# %%
def supersets(category):
    is_first_iter = True
    supersets = set()
    for serial in dict_items_info:
        metricCategoryID = dict_items_info[serial]['metricCategoryID']
        # Delete the first and last strings
        categories = metricCategoryID.split('_')[1:-1]
        if category in categories:
            if is_first_iter:
                supersets = set(categories)
                is_first_iter = False
            else:
                supersets = supersets.intersection()
    return supersets.difference

# %%
supersets('LEGGINGS')
# Out:
# {'LEGGINGS', 'TROUSERS'}

# %%
s = set('LEGGINGS')

# %%
s.add(1)

# %%
s
# Out:
# {1}

# %%
s.intersection([0])
# Out:
# set()

# %%
s
# Out:
# {1}

# %%
s = set(['hello', 1, 13])

# %%
type(s)
# Out:
# set
